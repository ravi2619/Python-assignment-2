# %%
for i in range(5):
    for j in range(i):
        print('*',end="")
    print()
for i in range(5):
    for j in range(5-i):
        print('*',end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
user=input('Enter word ')
l=[]
for i in range(len(user)):
    l.append(user[(len(user)-1)-i])
print("".join(l))
#or
print(user[::-1])
